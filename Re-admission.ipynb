# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Readmission.xlsx')

# %%
df
# Out:
#                    race  gender      age  time_in_hospital  \
# 0             Caucasian  Female   [0-10)                 1
# 1             Caucasian  Female  [10-20)                 3
# 2       AfricanAmerican  Female  [20-30)                 2
# 3             Caucasian    Male  [30-40)                 2
# 4             Caucasian    Male  [40-50)                 1
# ...                 ...     ...      ...               ...
# 101761  AfricanAmerican    Male  [70-80)                 3
# 101762  AfricanAmerican  Female  [80-90)                 5
# 101763        Caucasian    Male  [70-80)                 1
# 101764        Caucasian  Female  [80-90)                10
# 101765        Caucasian    Male  [70-80)                 6
#
#         num_lab_procedures  num_procedures  num_medications  number_emergency  \
# 0                       41               0                1                 0
# 1                       59               0               18                 0
# ...

# %%
df.isnull().sum()
# Out:
# race                  0
# gender                0
# age                   0
# time_in_hospital      0
# num_lab_procedures    0
# num_procedures        0
# num_medications       0
# number_emergency      0
# diag_1                0
# diag_2                0
# diag_3                0
# change                0
# diabetesMed           0
# readmitted            0
# dtype: int64

# %%
for col in df.columns:
    if df[col].dtype == object:
        print(col,df[col][df[col] == '?'].count())
# Out:
# race 2273
# gender 0
# age 0
# diag_1 21
# diag_2 358
# diag_3 1423
# change 0
# diabetesMed 0
# readmitted 0

# %%
df.columns
# Out:
# Index(['race', 'gender', 'age', 'time_in_hospital', 'num_lab_procedures',
#        'num_procedures', 'num_medications', 'number_emergency', 'diag_1',
#        'diag_2', 'diag_3', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df
# Out:
#                    race  gender      age  time_in_hospital  \
# 0             Caucasian  Female   [0-10)                 1
# 1             Caucasian  Female  [10-20)                 3
# 2       AfricanAmerican  Female  [20-30)                 2
# 3             Caucasian    Male  [30-40)                 2
# 4             Caucasian    Male  [40-50)                 1
# ...                 ...     ...      ...               ...
# 101761  AfricanAmerican    Male  [70-80)                 3
# 101762  AfricanAmerican  Female  [80-90)                 5
# 101763        Caucasian    Male  [70-80)                 1
# 101764        Caucasian  Female  [80-90)                10
# 101765        Caucasian    Male  [70-80)                 6
#
#         num_lab_procedures  num_procedures  num_medications  number_emergency  \
# 0                       41               0                1                 0
# 1                       59               0               18                 0
# ...

# %%
df['change'] = df['change'].replace('Ch', 1)
df['change'] = df['change'].replace('No', 0)

# %%
df
# Out:
#                    race  gender      age  time_in_hospital  \
# 0             Caucasian  Female   [0-10)                 1
# 1             Caucasian  Female  [10-20)                 3
# 2       AfricanAmerican  Female  [20-30)                 2
# 3             Caucasian    Male  [30-40)                 2
# 4             Caucasian    Male  [40-50)                 1
# ...                 ...     ...      ...               ...
# 101761  AfricanAmerican    Male  [70-80)                 3
# 101762  AfricanAmerican  Female  [80-90)                 5
# 101763        Caucasian    Male  [70-80)                 1
# 101764        Caucasian  Female  [80-90)                10
# 101765        Caucasian    Male  [70-80)                 6
#
#         num_lab_procedures  num_procedures  num_medications  number_emergency  \
# 0                       41               0                1                 0
# 1                       59               0               18                 0
# ...

# %%
df["gender"] = df["gender"].drop(df[df["gender"] == "Unknown/Invalid"].index, axis=0)

# %%
df['readmitted'] = df['readmitted'].replace('>30', 0)
df['readmitted'] = df['readmitted'].replace('<30', 1)
df['readmitted'] = df['readmitted'].replace('NO', 0)

# %%
df['gender'] = df['gender'].replace('Male', 1)
df['gender'] = df['gender'].replace('Female', 0)

# %%
df
# Out:
#                    race  gender      age  time_in_hospital  \
# 0             Caucasian     0.0   [0-10)                 1
# 1             Caucasian     0.0  [10-20)                 3
# 2       AfricanAmerican     0.0  [20-30)                 2
# 3             Caucasian     1.0  [30-40)                 2
# 4             Caucasian     1.0  [40-50)                 1
# ...                 ...     ...      ...               ...
# 101761  AfricanAmerican     1.0  [70-80)                 3
# 101762  AfricanAmerican     0.0  [80-90)                 5
# 101763        Caucasian     1.0  [70-80)                 1
# 101764        Caucasian     0.0  [80-90)                10
# 101765        Caucasian     1.0  [70-80)                 6
#
#         num_lab_procedures  num_procedures  num_medications  number_emergency  \
# 0                       41               0                1                 0
# 1                       59               0               18                 0
# ...

# %%
df['diabetesMed'] = df['diabetesMed'].replace('Yes', 1)
df['diabetesMed'] = df['diabetesMed'].replace('No', 0)

# %%
df.isnull().sum()
# Out:
# race                  0
# gender                3
# age                   0
# time_in_hospital      0
# num_lab_procedures    0
# num_procedures        0
# num_medications       0
# number_emergency      0
# diag_1                0
# diag_2                0
# diag_3                0
# change                0
# diabetesMed           0
# readmitted            0
# dtype: int64

# %%
df.dropna(subset = ['gender'], inplace = True)

# %%
df.isnull().sum()
# Out:
# race                  0
# gender                0
# age                   0
# time_in_hospital      0
# num_lab_procedures    0
# num_procedures        0
# num_medications       0
# number_emergency      0
# diag_1                0
# diag_2                0
# diag_3                0
# change                0
# diabetesMed           0
# readmitted            0
# dtype: int64

# %%
df
# Out:
#                    race  gender      age  time_in_hospital  \
# 0             Caucasian     0.0   [0-10)                 1
# 1             Caucasian     0.0  [10-20)                 3
# 2       AfricanAmerican     0.0  [20-30)                 2
# 3             Caucasian     1.0  [30-40)                 2
# 4             Caucasian     1.0  [40-50)                 1
# ...                 ...     ...      ...               ...
# 101761  AfricanAmerican     1.0  [70-80)                 3
# 101762  AfricanAmerican     0.0  [80-90)                 5
# 101763        Caucasian     1.0  [70-80)                 1
# 101764        Caucasian     0.0  [80-90)                10
# 101765        Caucasian     1.0  [70-80)                 6
#
#         num_lab_procedures  num_procedures  num_medications  number_emergency  \
# 0                       41               0                1                 0
# 1                       59               0               18                 0
# ...

# %%
for col in df.columns:
    if df[col].dtype == object:
        print(col,df[col][df[col] == '?'].count())
# Out:
# race 2271
# age 0
# diag_1 21
# diag_2 358
# diag_3 1423

# %%
for i in range(0,10):
    df['age'] = df['age'].replace('['+str(10*i)+'-'+str(10*(i+1))+')', i+1)

# %%
df['age'].value_counts()
# Out:
# 8     26066
# 7     22482
# 6     17256
# 9     17197
# 5      9685
# 4      3775
# 10     2793
# 3      1657
# 2       691
# 1       161
# Name: age, dtype: int64

# %%
df
# Out:
#                    race  gender  age  time_in_hospital  num_lab_procedures  \
# 0             Caucasian     0.0    1                 1                  41
# 1             Caucasian     0.0    2                 3                  59
# 2       AfricanAmerican     0.0    3                 2                  11
# 3             Caucasian     1.0    4                 2                  44
# 4             Caucasian     1.0    5                 1                  51
# ...                 ...     ...  ...               ...                 ...
# 101761  AfricanAmerican     1.0    8                 3                  51
# 101762  AfricanAmerican     0.0    9                 5                  33
# 101763        Caucasian     1.0    8                 1                  53
# 101764        Caucasian     0.0    9                10                  45
# 101765        Caucasian     1.0    8                 6                  13
#
# ...

# %%
rdx = df[df['race'] == '?'].index

# %%
df = df.drop(rdx, axis = 0)

# %%
df
# Out:
#                    race  gender  age  time_in_hospital  num_lab_procedures  \
# 0             Caucasian     0.0    1                 1                  41
# 1             Caucasian     0.0    2                 3                  59
# 2       AfricanAmerican     0.0    3                 2                  11
# 3             Caucasian     1.0    4                 2                  44
# 4             Caucasian     1.0    5                 1                  51
# ...                 ...     ...  ...               ...                 ...
# 101761  AfricanAmerican     1.0    8                 3                  51
# 101762  AfricanAmerican     0.0    9                 5                  33
# 101763        Caucasian     1.0    8                 1                  53
# 101764        Caucasian     0.0    9                10                  45
# 101765        Caucasian     1.0    8                 6                  13
#
# ...

# %%
for col in df.columns:
    if df[col].dtype == object:
        print(col,df[col][df[col] == '?'].count())
# Out:
# race 0
# diag_1 19
# diag_2 336
# diag_3 1349

# %%
d1x = df[df['diag_1'] == '?'].index

# %%
df = df.drop(d1x, axis = 0)

# %%
d2x = df[df['diag_2'] == '?'].index

# %%
df = df.drop(d2x, axis = 0)

# %%
d3x = df[df['diag_3'] == '?'].index

# %%
df = df.drop(d3x, axis = 0)

# %%
df
# Out:
#                    race  gender  age  time_in_hospital  num_lab_procedures  \
# 1             Caucasian     0.0    2                 3                  59
# 2       AfricanAmerican     0.0    3                 2                  11
# 3             Caucasian     1.0    4                 2                  44
# 4             Caucasian     1.0    5                 1                  51
# 5             Caucasian     1.0    6                 3                  31
# ...                 ...     ...  ...               ...                 ...
# 101761  AfricanAmerican     1.0    8                 3                  51
# 101762  AfricanAmerican     0.0    9                 5                  33
# 101763        Caucasian     1.0    8                 1                  53
# 101764        Caucasian     0.0    9                10                  45
# 101765        Caucasian     1.0    8                 6                  13
#
# ...

# %%
df['race'].value_counts()
# Out:
# Caucasian          75079
# AfricanAmerican    18881
# Hispanic            1984
# Other               1483
# Asian                625
# Name: race, dtype: int64

# %%
df['race'] = df['race'].replace('Caucasian', 1)

# %%
df['race'] = df['race'].replace('AfricanAmerican', 2)
df['race'] = df['race'].replace('Hispanic', 3)
df['race'] = df['race'].replace('Asian', 4)
df['race'] = df['race'].replace('Other', 5)

# %%
df
# Out:
#         race  gender  age  time_in_hospital  num_lab_procedures  \
# 1          1     0.0    2                 3                  59
# 2          2     0.0    3                 2                  11
# 3          1     1.0    4                 2                  44
# 4          1     1.0    5                 1                  51
# 5          1     1.0    6                 3                  31
# ...      ...     ...  ...               ...                 ...
# 101761     2     1.0    8                 3                  51
# 101762     2     0.0    9                 5                  33
# 101763     1     1.0    8                 1                  53
# 101764     1     0.0    9                10                  45
# 101765     1     1.0    8                 6                  13
#
#         num_procedures  num_medications  number_emergency  diag_1  diag_2  \
# 1                    0               18                 0     276  250.01
# ...

# %%
df['diag_1'].str.contains('V').value_counts()
# Out:
# True     1600
# False       1
# Name: diag_1, dtype: int64

# %%
df.isnull().sum()
# Out:
# race                  0
# gender                0
# age                   0
# time_in_hospital      0
# num_lab_procedures    0
# num_procedures        0
# num_medications       0
# number_emergency      0
# diag_1                0
# diag_2                0
# diag_3                0
# change                0
# diabetesMed           0
# readmitted            0
# dtype: int64

# %%
for col in df.columns:
    if df[col].dtype == object:
        print(col,df[col][df[col] == '?'].count())
# Out:
# diag_1 0
# diag_2 0
# diag_3 0

# %%
df['level1_diag1'] = df['diag_1']
df['level2_diag1'] = df['diag_1']
df['level1_diag2'] = df['diag_2']
df['level2_diag2'] = df['diag_2']
df['level1_diag3'] = df['diag_3']
df['level2_diag3'] = df['diag_3']

# %%
df['diag_1'].str.contains('V | E').value_counts()
# Out:
# False    1601
# Name: diag_1, dtype: int64

# %%
df["diag_1"] = df["diag_1"].str.apply(lambda x: x.replace("V", "0", regex = True)
# Out:
#   File "C:\Users\gurup\AppData\Local\Temp/ipykernel_9428/2525265020.py", line 3
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
df['diag_1'] = df['diag_1'].str.replace('[V]', 'ab', regex = True)

# %%
df['diag_1'].str.contains('V | E').value_counts()
# Out:
# False    1601
# Name: diag_1, dtype: int64

# %%
df
# Out:
#         race  gender  age  time_in_hospital  num_lab_procedures  \
# 1          1     0.0    2                 3                  59
# 2          2     0.0    3                 2                  11
# 3          1     1.0    4                 2                  44
# 4          1     1.0    5                 1                  51
# 5          1     1.0    6                 3                  31
# ...      ...     ...  ...               ...                 ...
# 101761     2     1.0    8                 3                  51
# 101762     2     0.0    9                 5                  33
# 101763     1     1.0    8                 1                  53
# 101764     1     0.0    9                10                  45
# 101765     1     1.0    8                 6                  13
#
#         num_procedures  num_medications  number_emergency diag_1  diag_2  \
# 1                    0               18                 0    NaN  250.01
# ...

# %%
df.to_csv('Refined.csv')

# %%
df = pd.read_csv('')

# %%
for col in df.columns:
    if df[col].dtype == object:
         print(col,df[col][df[col] == '?'].count())
            
print('gender', df['gender'][df['gender'] == 'Unknown/Invalid'].count())
# Out:
# race 2271
# diag_1 21
# diag_2 358
# diag_3 1423
# gender 0

# %%
df1 = pd.read_csv('sairam.csv')

# %%
df1
# Out:
#        race  gender  age  time_in_hospital  num_lab_procedures  \
# 0         1       0    2                 3                  59
# 1         2       0    3                 2                  11
# 2         1       1    4                 2                  44
# 3         1       1    5                 1                  51
# 4         1       1    6                 3                  31
# ...     ...     ...  ...               ...                 ...
# 98047     2       1    8                 3                  51
# 98048     2       0    9                 5                  33
# 98049     1       1    8                 1                  53
# 98050     1       0    9                10                  45
# 98051     1       1    8                 6                  13
#
#        num_procedures  num_medications  number_emergency  diag_1  diag_2  \
# 0                   0               18                 0       2       2
# ...

# %%
x = df1.drop('readmitted', axis = 1)

# %%
y = df1['readmitted']

# %%
x
# Out:
#        race  gender  age  time_in_hospital  num_lab_procedures  \
# 0         1       0    2                 3                  59
# 1         2       0    3                 2                  11
# 2         1       1    4                 2                  44
# 3         1       1    5                 1                  51
# 4         1       1    6                 3                  31
# ...     ...     ...  ...               ...                 ...
# 98047     2       1    8                 3                  51
# 98048     2       0    9                 5                  33
# 98049     1       1    8                 1                  53
# 98050     1       0    9                10                  45
# 98051     1       1    8                 6                  13
#
#        num_procedures  num_medications  number_emergency  diag_1  diag_2  \
# 0                   0               18                 0       2       2
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 98047    0
# 98048    0
# 98049    0
# 98050    0
# 98051    0
# Name: readmitted, Length: 98052, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train , y_test = train_test_split(x,y, test_size = 0.30, random_state = 0)

# %%
x_train
# Out:
#        race  gender  age  time_in_hospital  num_lab_procedures  \
# 60842     1       1    9                 4                  70
# 97495     1       1    6                 4                  46
# 63227     1       1   10                 3                  63
# 33328     1       1    7                 6                  38
# 53999     2       1    8                 3                  57
# ...     ...     ...  ...               ...                 ...
# 21243     2       0    9                 6                  64
# 45891     2       1    8                 2                  52
# 42613     1       0    8                14                   1
# 43567     1       0    8                 8                  31
# 68268     1       1    8                 3                  56
#
#        num_procedures  num_medications  number_emergency  diag_1  diag_2  \
# 60842               0               16                 0       7       2
# ...

# %%
y_train
# Out:
# 60842    0
# 97495    0
# 63227    0
# 33328    0
# 53999    0
#         ..
# 21243    0
# 45891    0
# 42613    0
# 43567    0
# 68268    1
# Name: readmitted, Length: 68636, dtype: int64

# %%
x_test
# Out:
#        race  gender  age  time_in_hospital  num_lab_procedures  \
# 97995     1       1    8                 3                  66
# 70658     2       1    6                 2                   4
# 92357     1       1    8                 2                  29
# 13083     1       1    5                 4                  56
# 93453     1       1    7                 5                  40
# ...     ...     ...  ...               ...                 ...
# 17120     1       0    8                 2                  54
# 65190     1       0   10                 3                  43
# 35286     1       0    5                 4                  49
# 28930     1       0   10                 1                  69
# 96877     1       0    2                 3                   1
#
#        num_procedures  num_medications  number_emergency  diag_1  diag_2  \
# 97995               1               18                 0       6       6
# ...

# %%
y_test
# Out:
# 97995    0
# 70658    0
# 92357    1
# 13083    0
# 93453    0
#         ..
# 17120    0
# 65190    0
# 35286    1
# 28930    0
# 96877    0
# Name: readmitted, Length: 29416, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()

# %%
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[22607  3456]
#  [ 2835   518]]
# 0.7861367963013326

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(x_train, y_train)
DecisionTreeClassifier(criterion='entropy', random_state=0)
y_pred = classifier.predict(x_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)

# %%
df1
# Out:
#        race  gender  age  time_in_hospital  num_lab_procedures  \
# 0         1       0    2                 3                  59
# 1         2       0    3                 2                  11
# 2         1       1    4                 2                  44
# 3         1       1    5                 1                  51
# 4         1       1    6                 3                  31
# ...     ...     ...  ...               ...                 ...
# 98047     2       1    8                 3                  51
# 98048     2       0    9                 5                  33
# 98049     1       1    8                 1                  53
# 98050     1       0    9                10                  45
# 98051     1       1    8                 6                  13
#
#        num_procedures  num_medications  number_emergency  diag_1  diag_2  \
# 0                   0               18                 0       2       2
# ...

# %%
df1['Stay_score'] = df1['time_in_hospital'] * 1

# %%
df1
# Out:
#        race  gender  age  time_in_hospital  num_lab_procedures  \
# 0         1       0    2                 3                  59
# 1         2       0    3                 2                  11
# 2         1       1    4                 2                  44
# 3         1       1    5                 1                  51
# 4         1       1    6                 3                  31
# ...     ...     ...  ...               ...                 ...
# 98047     2       1    8                 3                  51
# 98048     2       0    9                 5                  33
# 98049     1       1    8                 1                  53
# 98050     1       0    9                10                  45
# 98051     1       1    8                 6                  13
#
#        num_procedures  num_medications  number_emergency  diag_1  diag_2  \
# 0                   0               18                 0       2       2
# ...

# %%
df1['Stay_score'] = df1['Stay_score'].apply(lambda x : 1 if x<= 1 else x )
df1['Stay_score'] = df1['Stay_score'].apply(lambda x : 2 if x> 1 and x<= 2 else x )
df1['Stay_score'] = df1['Stay_score'].apply(lambda x : 3 if x> 2 and x<= 3 else x )
df1['Stay_score'] = df1['Stay_score'].apply(lambda x : 4 if x>4  and x<= 6 else x )
df1['Stay_score'] = df1['Stay_score'].apply(lambda x : 5 if x>6  and x<= 13 else x )
df1['Stay_score'] = df1['Stay_score'].apply(lambda x : 6 if x == 14 else x )

# %%
df1
# Out:
#        race  gender  age  time_in_hospital  num_lab_procedures  \
# 0         1       0    2                 3                  59
# 1         2       0    3                 2                  11
# 2         1       1    4                 2                  44
# 3         1       1    5                 1                  51
# 4         1       1    6                 3                  31
# ...     ...     ...  ...               ...                 ...
# 98047     2       1    8                 3                  51
# 98048     2       0    9                 5                  33
# 98049     1       1    8                 1                  53
# 98050     1       0    9                10                  45
# 98051     1       1    8                 6                  13
#
#        num_procedures  num_medications  number_emergency  diag_1  diag_2  \
# 0                   0               18                 0       2       2
# ...

# %%
df1['Emergency_score'] = df1['number_emergency']*1

# %%
df1
# Out:
#        race  gender  age  time_in_hospital  num_lab_procedures  \
# 0         1       0    2                 3                  59
# 1         2       0    3                 2                  11
# 2         1       1    4                 2                  44
# 3         1       1    5                 1                  51
# 4         1       1    6                 3                  31
# ...     ...     ...  ...               ...                 ...
# 98047     2       1    8                 3                  51
# 98048     2       0    9                 5                  33
# 98049     1       1    8                 1                  53
# 98050     1       0    9                10                  45
# 98051     1       1    8                 6                  13
#
#        num_procedures  num_medications  number_emergency  diag_1  diag_2  \
# 0                   0               18                 0       2       2
# ...

# %%
df1['Emergency_score'] = df1['Emergency_score'].apply(lambda x : 3 if x> 0 else x )

# %%
df1.head(12)
# Out:
#     race  gender  age  time_in_hospital  num_lab_procedures  num_procedures  \
# 0      1       0    2                 3                  59               0
# 1      2       0    3                 2                  11               5
# 2      1       1    4                 2                  44               1
# 3      1       1    5                 1                  51               0
# 4      1       1    6                 3                  31               6
# 5      1       1    7                 4                  70               1
# 6      1       1    8                 5                  73               0
# 7      1       0    9                13                  68               2
# 8      1       0   10                12                  33               3
# 9      2       0    5                 9                  47               2
# 10     2       1    7                 7                  62               0
# ...

# %%
df1['Admission type'] = np.random.randint(0, 2, df1.shape[0])

# %%
df1['Admission type'].value_counts()
# Out:
# 1    49093
# 0    48959
# Name: Admission type, dtype: int64

# %%
df1
# Out:
#        race  gender  age  time_in_hospital  num_lab_procedures  \
# 0         1       0    2                 3                  59
# 1         2       0    3                 2                  11
# 2         1       1    4                 2                  44
# 3         1       1    5                 1                  51
# 4         1       1    6                 3                  31
# ...     ...     ...  ...               ...                 ...
# 98047     2       1    8                 3                  51
# 98048     2       0    9                 5                  33
# 98049     1       1    8                 1                  53
# 98050     1       0    9                10                  45
# 98051     1       1    8                 6                  13
#
#        num_procedures  num_medications  number_emergency  diag_1  diag_2  \
# 0                   0               18                 0       2       2
# ...

# %%
df1['diag_1_score'] = df1['diag_1']*1

# %%
df1
# Out:
#        race  gender  age  time_in_hospital  num_lab_procedures  \
# 0         1       0    2                 3                  59
# 1         2       0    3                 2                  11
# 2         1       1    4                 2                  44
# 3         1       1    5                 1                  51
# 4         1       1    6                 3                  31
# ...     ...     ...  ...               ...                 ...
# 98047     2       1    8                 3                  51
# 98048     2       0    9                 5                  33
# 98049     1       1    8                 1                  53
# 98050     1       0    9                10                  45
# 98051     1       1    8                 6                  13
#
#        num_procedures  num_medications  number_emergency  diag_1  diag_2  \
# 0                   0               18                 0       2       2
# ...

# %%
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 3 if x == 0 else x) 
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 3 if x == 4 else x) 
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 3 if x == 5 else x) 
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 3 if x == 11 else x)
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 3 if x == 12 else x) 
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 2 if x == 1 else x) 
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 2 if x == 2 else x)
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 2 if x == 7 else x)
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 2 if x == 8 else x)
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 2 if x == 9 else x)
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 2 if x == 14 else x)
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 2 if x == 15 else x)
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 2 if x == 8 else x)
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 1 if x == 6 else x)
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 1 if x == 10 else x)
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 1 if x == 13 else x)
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 1 if x == 17 else x)
df1['diag_1_score'] = df1['diag_1_score'].apply(lambda x : 1 if x == 16 else x)

# %%
df1['diag_1_score'].value_counts()
# Out:
# 2    75488
# 3    15861
# 1     6703
# Name: diag_1_score, dtype: int64

# %%
df1
# Out:
#        race  gender  age  time_in_hospital  num_lab_procedures  \
# 0         1       0    2                 3                  59
# 1         2       0    3                 2                  11
# 2         1       1    4                 2                  44
# 3         1       1    5                 1                  51
# 4         1       1    6                 3                  31
# ...     ...     ...  ...               ...                 ...
# 98047     2       1    8                 3                  51
# 98048     2       0    9                 5                  33
# 98049     1       1    8                 1                  53
# 98050     1       0    9                10                  45
# 98051     1       1    8                 6                  13
#
#        num_procedures  num_medications  number_emergency  diag_1  diag_2  \
# 0                   0               18                 0       2       2
# ...

# %%
df1.to_csv('LACE.csv')

# %%
df1 = df1.drop('diag_3', axis = 1)

# %%
df1 = df1.drop('diag_2', axis = 1)

# %%
df1
# Out:
#        race  gender  age  time_in_hospital  num_lab_procedures  \
# 0         1       0    2                 3                  59
# 1         2       0    3                 2                  11
# 2         1       1    4                 2                  44
# 3         1       1    5                 1                  51
# 4         1       1    6                 3                  31
# ...     ...     ...  ...               ...                 ...
# 98047     2       1    8                 3                  51
# 98048     2       0    9                 5                  33
# 98049     1       1    8                 1                  53
# 98050     1       0    9                10                  45
# 98051     1       1    8                 6                  13
#
#        num_procedures  num_medications  number_emergency  diag_1  change  \
# 0                   0               18                 0       2       1
# ...

# %%
df1['LACE_Score'] = df1['Stay_score']+df1['Admission type']+ df1['diag_1_score']+df1['Emergency_score']

# %%
df1
# Out:
#        race  gender  age  time_in_hospital  num_lab_procedures  \
# 0         1       0    2                 3                  59
# 1         2       0    3                 2                  11
# 2         1       1    4                 2                  44
# 3         1       1    5                 1                  51
# 4         1       1    6                 3                  31
# ...     ...     ...  ...               ...                 ...
# 98047     2       1    8                 3                  51
# 98048     2       0    9                 5                  33
# 98049     1       1    8                 1                  53
# 98050     1       0    9                10                  45
# 98051     1       1    8                 6                  13
#
#        num_procedures  num_medications  number_emergency  diag_1  change  \
# 0                   0               18                 0       2       1
# ...

# %%
df1['LACE_Score'].value_counts()
# Out:
# 7     22237
# 6     20552
# 5     14714
# 8     12624
# 4     12543
# 3      5758
# 9      4793
# 10     2842
# 11     1326
# 2       367
# 12      281
# 13       15
# Name: LACE_Score, dtype: int64

# %%
# Out:
#        race  gender  age  time_in_hospital  num_lab_procedures  \
# 0         1       0    2                 3                  59
# 1         2       0    3                 2                  11
# 2         1       1    4                 2                  44
# 3         1       1    5                 1                  51
# 4         1       1    6                 3                  31
# ...     ...     ...  ...               ...                 ...
# 98046     2       0    7                 6                  45
# 98047     2       1    8                 3                  51
# 98048     2       0    9                 5                  33
# 98049     1       1    8                 1                  53
# 98050     1       0    9                10                  45
#
#        num_procedures  num_medications  number_emergency  diag_1  change  \
# 0                   0               18                 0       2       1
# ...

# %%
x = df1.drop('readmitted', axis = 1)

# %%
y = df1['readmitted']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train , y_test = train_test_split(x,y, test_size = 0.30, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(x_train, y_train)
DecisionTreeClassifier(criterion='entropy', random_state=0)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = classifier.predict(x_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[22739  3324]
#  [ 2863   490]]
# 0.7896722871906445

# %%
df1
# Out:
#        race  gender  age  time_in_hospital  num_lab_procedures  \
# 0         1       0    2                 3                  59
# 1         2       0    3                 2                  11
# 2         1       1    4                 2                  44
# 3         1       1    5                 1                  51
# 4         1       1    6                 3                  31
# ...     ...     ...  ...               ...                 ...
# 98047     2       1    8                 3                  51
# 98048     2       0    9                 5                  33
# 98049     1       1    8                 1                  53
# 98050     1       0    9                10                  45
# 98051     1       1    8                 6                  13
#
#        num_procedures  num_medications  number_emergency  diag_1  change  \
# 0                   0               18                 0       2       1
# ...

# %%
df1.to_csv('Readmission_predictor.csv')
